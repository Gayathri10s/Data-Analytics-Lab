# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
pd.read_csv("athlete1.csv")
dat=pd.read_csv("athlete1.csv")
df=pd.DataFrame(dat)

# %%
sample_data={'Height':np.random.rand(20),
      'Weight': np.random.rand(20)}
df1= pd.DataFrame(sample_data)

# %%
df1.plot.scatter(x='Height', y='Weight', style='o')

# %%
df1.plot(x='Height', y='Weight', color='Green')

# %%
df1.plot.scatter(x='Height', y='Weight', s=np.pi*3, c='Red')
